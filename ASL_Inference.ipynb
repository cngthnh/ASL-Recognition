# %%
# !nvidia-smi
# Out:
# Thu Dec  9 13:45:37 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/cngthnh/custom-template.git template
# %cd /content/template
# !git checkout inference
# !git pull origin inference
# Out:
# Cloning into 'template'...
# remote: Enumerating objects: 2105, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 2105 (delta 82), reused 70 (delta 70), pack-reused 1997
# Receiving objects: 100% (2105/2105), 9.46 MiB | 20.83 MiB/s, done.
# Resolving deltas: 100% (1237/1237), done.
# /content/template
# Branch 'inference' set up to track remote branch 'inference' from 'origin'.
# Switched to a new branch 'inference'
# From https://github.com/cngthnh/custom-template
#  * branch            inference  -> FETCH_HEAD
# Already up to date.

# %%
# %%capture
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/template
# Out:
# /content/template

# %%
# !python inference.py --detector_weight='/content/drive/MyDrive/Projects/Hand Detection/yolov5m_best.pth' --classifier_weight='/content/drive/MyDrive/Projects/Classification/b5_mixed_val/efficientnet_b5_best.pth' --input_path="/content/drive/MyDrive/Projects/Test/ASL_new_test" --output_path="/content/result.csv" --min_conf=0.2 --visualized="/content/drive/MyDrive/Projects/Test/final_result" --no_visualization
# Out:
# Load configs from weight
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# File exists: ./.cache/yolo5m.pth
# Loaded pretrained model
# Loaded Successfully!
# No pretrained weights exist for this model. Using random initialization.
# Loaded Successfully!
# ##########   CONFIGURATION INFO   ##########
# project_name:	cocohand
# train_imgs:	train
# val_imgs:	val
# test_imgs:	None
# train_anns:	train/instances_train.json
# val_anns:	val/instances_val.json
# model_name:	yolov5m
# gpu_devices:	0
# num_epochs:	100
# batch_size:	16
# num_workers:	2
# fusion_mode:	nms
# min_iou_val:	0.5
# min_conf_val:	0.01
# max_images_val:	10000
# ...
